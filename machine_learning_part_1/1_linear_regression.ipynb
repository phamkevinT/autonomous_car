# %% [markdown]
# # Linear Regression

# %% [markdown]
# Let's fabricate some data that shows a roughly linear relationship between average vehicle speed, and bumpiness of the road. In the real world, LIDAR data might be used on a self-driving car to measure the road conditions, and the vehicle might need to adjust its speed accordingly.

# %%
pip install seaborn
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting seaborn
#   Downloading seaborn-0.12.1-py3-none-any.whl (288 kB)
#      -------------------------------------- 288.2/288.2 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=0.25 in d:\python_projects\mlds_course\fundamentals\env\lib\site-packages (from seaborn) (1.4.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in d:\python_projects\mlds_course\fundamentals\env\lib\site-packages (from seaborn) (3.5.3)
# Requirement already satisfied: numpy>=1.17 in d:\python_projects\mlds_course\fundamentals\env\lib\site-packages (from seaborn) (1.23.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\python_projects\mlds_course\fundamentals\env\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in d:\python_projects\mlds_course\fundamentals\env\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\python_projects\mlds_course\fundamentals\env\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in d:\python_projects\mlds_course\fundamentals\env\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\python_projects\mlds_course\fundamentals\env\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in d:\python_projects\mlds_course\fundamentals\env\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (21.3)
# Requirement already satisfied: cycler>=0.10 in d:\python_projects\mlds_course\fundamentals\env\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in d:\python_projects\mlds_course\fundamentals\env\lib\site-packages (from pandas>=0.25->seaborn) (2022.1)
# Requirement already satisfied: six>=1.5 in d:\python_projects\mlds_course\fundamentals\env\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.12.1

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

vehicleSpeeds = np.random.normal(40.0, 10.0, 1000)
# Make up linear relationship between bumpiness and speed then add some randomness
bumpiness = (1.0 -(vehicleSpeeds / 70.0)) + np.random.normal(0, 0.1, 1000) 

plt.scatter(vehicleSpeeds, bumpiness)

# %% [markdown]
# As we only have two features, we can keep it simple and just use scipy.state.linregress:

# %%
from scipy import stats

slope, intercept, r_value, p_value, std_err = stats.linregress(vehicleSpeeds, bumpiness)

# %% [markdown]
# Not surprisngly, our R-squared value shows a decent fit:

# %%
r_value ** 2
# Out:
# 0.7015641714296105

# %% [markdown]
# Let's use the slope and intercept we got from the regression to plot predicted values vs. observed:

# %%
def predict(x):
    return slope * x + intercept

sns.set()

fitLine = predict(vehicleSpeeds)

plt.scatter(vehicleSpeeds, bumpiness)
plt.plot(vehicleSpeeds, fitLine, c='r')
plt.show()

# %% [markdown]
# ## Activity

# %% [markdown]
# Try increasing the random variation in the test data, and see what effect it has on the r-squared error value.

# %%
# vehicleSpeeds = np.random.normal(40.0, 5.0, 1000) # Changed the standard deviation from 10 to 5
# bumpiness = (1.0 -(vehicleSpeeds / 70.0)) + np.random.normal(0, 0.1, 1000)
