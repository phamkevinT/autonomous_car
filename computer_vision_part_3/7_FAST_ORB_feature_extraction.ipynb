# %% [markdown]
# ## CODE TO PERFORM FEATURE DETECTION

# %% [markdown]
# Photo Credit: https://commons.wikimedia.org/wiki/File:Truckrr.png (Limtu)

# %% [markdown]
# # LOAD/DISPLAY IMAGE

# %%
import cv2
import numpy as np
import matplotlib.image as mpimg
from matplotlib import pyplot as plt
# %matplotlib inline

image_color = cv2.imread('truckrr.png')
# image_color = mpimg.imread('Truck_detection.jpg') # import image as RGB instead of BGR 


cv2.imshow('Truck', image_color)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
height, width = image_color.shape[:2]

# %%
height
# Out:
# 450

# %%
width
# Out:
# 769

# %%
plt.imshow(image_color)

# %% [markdown]
# ## CONVERT TO GREYSCALE

# %%
image_gray = cv2.cvtColor(image_color, cv2.COLOR_BGR2GRAY)
plt.imshow(image_gray, cmap = 'gray')

# %%
image_gray.shape
# Out:
# (450, 769)

# %%
# Save the image in greyscale
# cv2.imwrite("Truck_grey.jpg", image_gray)

# %%
# Perform canny edge detection
threshold_1 = 20
threshold_2 = 250

image_canny = cv2.Canny(image_gray, threshold_1, threshold_2)

cv2.imshow('Canny', image_canny)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # PERFORM FEATURE DETECTION

# %%
# Create FAST Detector object
fast = cv2.FastFeatureDetector_create()

# Identify the important pixels
keypoints = fast.detect(image_gray, None)

print ("Number of keypoints Detected: ", len(keypoints))

# Draw the important pixels
image = cv2.drawKeypoints(image_color, keypoints, None, color = (255,0,0))
#image = cv2.drawKeypoints(image_color, keypoints, None)


cv2.imshow('Feature Method - FAST', image)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# Number of keypoints Detected:  2371

# %%
# Create ORB object, we can specify the number of key points we desire
orb = cv2.ORB_create()

# Determine key points
keypoints = orb.detect(image_gray, None)

# Obtain the descriptors
keypoints, descriptors = orb.compute(image_gray, keypoints)
print("Number of keypoints Detected: ", len(keypoints))

# Draw rich keypoints on input image
image = cv2.drawKeypoints(image_color, keypoints,None, flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

cv2.imshow('Feature Method - ORB', image)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# Number of keypoints Detected:  500
